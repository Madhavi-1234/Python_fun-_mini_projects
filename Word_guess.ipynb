# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhavi-1234/Python_fun-_mini_projects/blob/main/Word_guess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print('Guess the word')

name = input("what is your name :") # Fixed typo "youre" to "your"
print("Good luck", name) # Fixed typo "nane" to "name"

words = ['rainbow', 'computer', 'science', 'programming',
         'python', 'mathematics', 'player', 'condition',
         'reverse', 'water', 'board', 'geeks']

word = random.choice(words)

guesses = ''

turns = 6

while turns > 0:

    failed = 0

    for char in word:
        if char in guesses: # Check against accumulated correct guesses
            print(char, end=" ") # Print the character if guessed
        else:
            print("_", end=" ") # Otherwise print underscore
            failed += 1 # Increment failed count if character not guessed
    print()

    if failed == 0:
        print("You won!")
        print(f"The word is {word}")
        break

    guess = input("Guess a character: ").lower() # Get new guess

    if len(guess) != 1:
        print("Please enter a single character to test your guess.")
        continue

    if guess in guesses:
        print('Hey, you already guessed that character.')
        continue

    guesses += guess

    if guess not in word: # Check if the guess is incorrect
        turns -= 1
        print('Your guess is wrong.')
        print(f"You have {turns} more chances.")

        if turns == 0:
            print("You lose!")
            print(f"The word was {word}")
# Out:
# Guess the word
# what is your name :Madhavi
# Good luck Madhavi
# _ _ _ _ _ _ _ _ _ _ _
# Guess a character: p
# Your guess is wrong.
# You have 5 more chances.
# _ _ _ _ _ _ _ _ _ _ _
# Guess a character: m
# m _ _ _ _ m _ _ _ _ _
# Guess a character: a
# m a _ _ _ m a _ _ _ _
# Guess a character: t
# m a t _ _ m a t _ _ _
# Guess a character: h
# m a t h _ m a t _ _ _
# Guess a character: e
# m a t h e m a t _ _ _
# Guess a character: m
# Hey, you already guessed that character.
# m a t h e m a t _ _ _
# Guess a character: a
# Hey, you already guessed that character.
# m a t h e m a t _ _ _
# Guess a character: t
# Hey, you already guessed that character.
# m a t h e m a t _ _ _
# Guess a character: i
# m a t h e m a t i _ _
# Guess a character: c
# m a t h e m a t i c _
# Guess a character: s
# m a t h e m a t i c s
# You won!
# The word is mathematics
