# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhavi-1234/Python_fun-_mini_projects/blob/main/Number_Guessing__Game_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## mini task- to get the better understanding about loops and conditon statements

# %%
##  Number Guessing Game

import random

print(' This is th fun and easy number guessing game . \n you have 7 chances to guess a number ')

low = int(input('Enter the low number :'))
high= int(input('enter the high number: '))

print( 'you have 7 chances to guess the number in betweeen low and high')

num= random.randint(low, high)

#total chance
chance= 7

# guess
gc= 0

while gc < chance:
  gc += 1


  guess= int(input("Enter the number :"))

  if guess== num :
      print(f" Your guess was correct.\n the nums is {num} and guess county was {gc}")
      break

 ## use less comdition elif gc > chance and guess != num:
      ## print( f"sorry! The number was { num}. Better luck next time!")

  elif guess > num :

      print( f"the number is too high. \n please try to guess again with a lower number ")

  elif guess < num :

     print( f" the numbe is too low .\n please try to guess again with a higher number ")
else:
  print( f"sorry! The number was { num}. Better luck next time!")
# Out:
#  This is th fun and easy number guessing game .
#  you have 7 chances to guess a number
# Enter the low number :1
# enter the high number: 12
# you have 7 chances to guess the number in betweeen low and high
# Enter the number :10
#  the numbe is too low .
#  please try to guess again with a higher number
# Enter the number :11
#  Your guess was correct.
#  the nums is 11 and guess county was 2
